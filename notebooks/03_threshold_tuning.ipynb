# %%
# Stage 3 – Threshold Tuning

This notebook performs systematic threshold tuning for:

- Segment-level anomaly threshold
- Video-level anomaly ratio threshold

The goal is to find the best F1-score under a balanced decision rule.

# %%
import sys
import os
import numpy as np
import pandas as pd

from sklearn.metrics import classification_report

PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT)

import src.config as config
